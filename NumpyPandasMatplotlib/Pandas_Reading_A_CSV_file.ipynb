# %%
import pandas as pd

# %%
df = pd.read_csv('Data1.CSV')

# %%
df
# Out:
#        TRADE_NO TRADE_TIME SECTYPE SECURITY ISSUE_NAME TRADE_TYPE   TRADE_DT  \
# 0             1   10:41:15      GS   CG2017      8.07%         NR  01-Jan-03
# 1             2   10:41:24      GS   CG2017      7.49%         NR  01-Jan-03
# 2             3   10:41:26      GS   CG2017      7.46%         NR  01-Jan-03
# 3             4   10:41:29      GS   CG2017      7.46%         NR  01-Jan-03
# 4             5   10:41:31      GS   CG2017      7.49%         NR  01-Jan-03
# ...         ...        ...     ...      ...        ...        ...        ...
# 20670       352   17:15:43      GS   CG2017      8.07%         NR  31-Jan-03
# 20671       353   17:15:45      GS   CG2017      7.46%         NR  31-Jan-03
# 20672       354   17:15:48      GS   CG2012      9.40%         NR  31-Jan-03
# 20673       355   17:28:06      GS   CG2013      9.81%         NR  31-Jan-03
# 20674       357   17:37:04      GS   CG2012      7.40%         NR  31-Jan-03
#
# ...

# %%
df.head()
# Out:
#    TRADE_NO TRADE_TIME SECTYPE SECURITY ISSUE_NAME TRADE_TYPE   TRADE_DT  \
# 0         1   10:41:15      GS   CG2017      8.07%         NR  01-Jan-03
# 1         2   10:41:24      GS   CG2017      7.49%         NR  01-Jan-03
# 2         3   10:41:26      GS   CG2017      7.46%         NR  01-Jan-03
# 3         4   10:41:29      GS   CG2017      7.46%         NR  01-Jan-03
# 4         5   10:41:31      GS   CG2017      7.49%         NR  01-Jan-03
#
#     SETTL_DT  TRADE_QTY (Rs in Lacs)  PRICE_RATE(Rs.)  PRICE_YIELD ISSUE_DATE  \
# 0  01-Jan-03                   500.0           117.08        6.227  15-Jan-02
# 1  01-Jan-03                   500.0           111.95        6.216  16-Apr-02
# 2  01-Jan-03                   500.0           111.90        6.209  28-Aug-02
# 3  01-Jan-03                   500.0           111.89        6.210  28-Aug-02
# 4  01-Jan-03                   500.0           112.00        6.211  16-Apr-02
#
#   COUPON FREQUENCY   MAT_DATE
# ...

# %%
df['SECURITY'].dtype # 'O' for Object
# Out:
# dtype('O')

# %%
print(df['SECURITY'].dtype)
# Out:
# object

# %%
df['PRICE_YIELD'] # provides length as well as datatypes
# Out:
# 0        6.227
# 1        6.216
# 2        6.209
# 3        6.210
# 4        6.211
#          ...
# 20670    6.430
# 20671    6.480
# 20672    6.409
# 20673    6.304
# 20674    6.278
# Name: PRICE_YIELD, Length: 20675, dtype: float64

# %%
print(df['SECURITY'].astype('category'))
# Out:
# 0        CG2017
# 1        CG2017
# 2        CG2017
# 3        CG2017
# 4        CG2017
#           ...
# 20670    CG2017
# 20671    CG2017
# 20672    CG2012
# 20673    CG2013
# 20674    CG2012
# Name: SECURITY, Length: 20675, dtype: category
# Categories (25, object): ['364D', '91D', 'CG2003', 'CG2004', ..., 'CG2021', 'CG2022', 'CG2026', 'CG2032']
