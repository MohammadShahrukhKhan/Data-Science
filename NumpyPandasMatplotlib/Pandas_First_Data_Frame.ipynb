# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame() #creating an empty Data Frame

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1 = pd.DataFrame([[1,2,3,4],[5,6,7,8],[2,7,3,23],[3,6,8,23],[23,23,63,12]])

# %%
df1 #this table is only shown in jupyter notebook
# Out:
#     0   1   2   3
# 0   1   2   3   4
# 1   5   6   7   8
# 2   2   7   3  23
# 3   3   6   8  23
# 4  23  23  63  12

# %%
df1.head()
# Out:
#     0   1   2   3
# 0   1   2   3   4
# 1   5   6   7   8
# 2   2   7   3  23
# 3   3   6   8  23
# 4  23  23  63  12

# %%
df1.head(3) #takes first three rows and columns
# Out:
#    0  1  2   3
# 0  1  2  3   4
# 1  5  6  7   8
# 2  2  7  3  23

# %%
df1.tail(3) #takes last three rows and columns
# Out:
#     0   1   2   3
# 2   2   7   3  23
# 3   3   6   8  23
# 4  23  23  63  12
