# %%
import json as js

# %% [markdown]
# json stands for javascript object notation

# %%
js
# Out:
# <module 'json' from 'C:\\Python310\\lib\\json\\__init__.py'>

# %%
js_data = '{"a":1, "b":2, "c":3}'

# %%
x = js.loads(js_data)

# %%
x
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
x['a']
# Out:
# 1

# %% [markdown]
# creates a new file and dumps the data

# %%
with open('export.jason', 'w') as f:
    js.dump(x, f)
