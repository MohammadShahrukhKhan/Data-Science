# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame([[1,2,3,4],[5,6,7,8],[2,7,3,23],[3,6,8,23],[23,23,63,12]], columns=['A', 'B', 'C', 'D'])
df1
# Out:
#     A   B   C   D
# 0   1   2   3   4
# 1   5   6   7   8
# 2   2   7   3  23
# 3   3   6   8  23
# 4  23  23  63  12

# %%
df1.shape
# Out:
# (5, 4)

# %%
df1.iloc[0,1]
# Out:
# 2

# %%
df1.iloc[0:2,0:2] #slices a perticular matrix
# Out:
#    A  B
# 0  1  2
# 1  5  6

# %%
df1.iloc[0:2,1:3]
# Out:
#    B  C
# 0  2  3
# 1  6  7

# %%
df1.drop(['B', 'C'], axis=1) #drops column B and C
# Out:
#     A   D
# 0   1   4
# 1   5   8
# 2   2  23
# 3   3  23
# 4  23  12

# %%
df1.drop(columns=['B', 'C']) #does the same job
# Out:
#     A   D
# 0   1   4
# 1   5   8
# 2   2  23
# 3   3  23
# 4  23  12

# %%
df1.drop([1, 2]) #drops the rows
# Out:
#     A   B   C   D
# 0   1   2   3   4
# 3   3   6   8  23
# 4  23  23  63  12

# %%
df1.drop([0, 3])
# Out:
#     A   B   C   D
# 1   5   6   7   8
# 2   2   7   3  23
# 4  23  23  63  12
